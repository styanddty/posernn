# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from src.reader import PoseReader
from src.GlobalOpts import GlobalOpts

# %load_ext autoreload
# %autoreload 2

# %%
opts = GlobalOpts('testmodel')
reader = PoseReader('train', opts)
# Out:
# Generating train reader

# %%
print reader.pose.shape
# Out:
# (22246, 16, 2)

# %%
batchX, batchy = reader.get_batch(2)
print batchX.shape
print batchy.shape
# Out:
# (25, 224, 224, 3)
# (25, 16, 2)

# %%
for ind in range(opts.BATCH_SIZE):
    img = batchX[ind]
    label = batchy[ind]
    plt.figure()
    plt.imshow(img.astype(np.uint8))
    plt.plot(label[:,0], label[:,1], "o")
    plt.show()
